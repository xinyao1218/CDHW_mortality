# %%
from osgeo import gdal,osr,ogr
import cartopy.crs as ccrs
import numpy as np
import  matplotlib.pyplot as plt
import xarray as xr
import netCDF4 as nc
import scipy as sp
import geopandas as gpd
import pandas as pd
import glob
import rasterio
import rioxarray
import glob

# %%
file_paths = glob.glob("C:\\Users\yaoxin\Desktop\ISIMIP3b\\tasmax\*.nc")
# 合并数据集
combined_data = xr.Dataset()

for file_path in file_paths:
    ds = xr.open_dataset(file_path)
    ds = ds.sel(
    lat=slice(54, 3),
    lon=slice(73, 136)
)
    combined_data = xr.merge([combined_data, ds])
    ds.close()

ds = None

combined_data.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\com_tasmax\\gfdl-esm4_r1i1p1f1_w5e5_ssp585_tasmax_global_daily_2015_2100.nc')
combined_data = None

# %%
gfdl_his=xr.open_dataset('gfdl-esm4_r1i1p1f1_w5e5_historical_tasmax_global_daily_1941_2014.nc')
gfdl_ssp126=xr.open_dataset('gfdl-esm4_r1i1p1f1_w5e5_ssp126_tasmax_global_daily_2015_2100.nc')
gfdl_ssp370=xr.open_dataset('gfdl-esm4_r1i1p1f1_w5e5_ssp370_tasmax_global_daily_2015_2100.nc')
gfdl_ssp585=xr.open_dataset('gfdl-esm4_r1i1p1f1_w5e5_ssp585_tasmax_global_daily_2015_2100.nc')

ipsl_his=xr.open_dataset('ipsl-cm6a-lr_r1i1p1f1_w5e5_historical_tasmax_global_daily_1941_2014.nc')
ipsl_ssp126=xr.open_dataset('ipsl-cm6a-lr_r1i1p1f1_w5e5_ssp126_tasmax_global_daily_2015_2100.nc')
ipsl_ssp370=xr.open_dataset('ipsl-cm6a-lr_r1i1p1f1_w5e5_ssp370_tasmax_global_daily_2015_2100.nc')
ipsl_ssp585=xr.open_dataset('ipsl-cm6a-lr_r1i1p1f1_w5e5_ssp585_tasmax_global_daily_2015_2100.nc')


ipsl_his['time'] = ipsl_his['time'].dt.strftime('%Y-%m-%d')
ipsl_his['time'] = pd.to_datetime(ipsl_his['time'], format='%Y-%m-%d')

ipsl_ssp126['time'] = ipsl_ssp126['time'].dt.strftime('%Y-%m-%d')
ipsl_ssp126['time'] = pd.to_datetime(ipsl_ssp126['time'], format='%Y-%m-%d')

ipsl_ssp370['time'] = ipsl_ssp370['time'].dt.strftime('%Y-%m-%d')
ipsl_ssp370['time'] = pd.to_datetime(ipsl_ssp370['time'], format='%Y-%m-%d')

ipsl_ssp585['time'] = ipsl_ssp585['time'].dt.strftime('%Y-%m-%d')
ipsl_ssp585['time'] = pd.to_datetime(ipsl_ssp585['time'], format='%Y-%m-%d')


mpi_his=xr.open_dataset('mpi-esm1-2-hr_r1i1p1f1_w5e5_historical_tasmax_global_daily_1941_2014.nc')
mpi_ssp126=xr.open_dataset('mpi-esm1-2-hr_r1i1p1f1_w5e5_ssp126_tasmax_global_daily_2015_2100.nc')
mpi_ssp370=xr.open_dataset('mpi-esm1-2-hr_r1i1p1f1_w5e5_ssp370_tasmax_global_daily_2015_2100.nc')
mpi_ssp585=xr.open_dataset('mpi-esm1-2-hr_r1i1p1f1_w5e5_ssp585_tasmax_global_daily_2015_2100.nc')


mpi_his['time'] = mpi_his['time'].dt.strftime('%Y-%m-%d')
mpi_his['time'] = pd.to_datetime(mpi_his['time'], format='%Y-%m-%d')

mpi_ssp126['time'] = mpi_ssp126['time'].dt.strftime('%Y-%m-%d')
mpi_ssp126['time'] = pd.to_datetime(mpi_ssp126['time'], format='%Y-%m-%d')

mpi_ssp370['time'] = mpi_ssp370['time'].dt.strftime('%Y-%m-%d')
mpi_ssp370['time'] = pd.to_datetime(mpi_ssp370['time'], format='%Y-%m-%d')

mpi_ssp585['time'] = mpi_ssp585['time'].dt.strftime('%Y-%m-%d')
mpi_ssp585['time'] = pd.to_datetime(mpi_ssp585['time'], format='%Y-%m-%d')


mri_his=xr.open_dataset('mri-esm2-0_r1i1p1f1_w5e5_historical_tasmax_global_daily_1941_2014.nc')
mri_ssp126=xr.open_dataset('mri-esm2-0_r1i1p1f1_w5e5_ssp126_tasmax_global_daily_2015_2100.nc')
mri_ssp370=xr.open_dataset('mri-esm2-0_r1i1p1f1_w5e5_ssp370_tasmax_global_daily_2015_2100.nc')
mri_ssp585=xr.open_dataset('mri-esm2-0_r1i1p1f1_w5e5_ssp585_tasmax_global_daily_2015_2100.nc')


mri_his['time'] = mri_his['time'].dt.strftime('%Y-%m-%d')
mri_his['time'] = pd.to_datetime(mri_his['time'], format='%Y-%m-%d')

mri_ssp126['time'] = mri_ssp126['time'].dt.strftime('%Y-%m-%d')
mri_ssp126['time'] = pd.to_datetime(mri_ssp126['time'], format='%Y-%m-%d')

mri_ssp370['time'] = mri_ssp370['time'].dt.strftime('%Y-%m-%d')
mri_ssp370['time'] = pd.to_datetime(mri_ssp370['time'], format='%Y-%m-%d')

mri_ssp585['time'] = mri_ssp585['time'].dt.strftime('%Y-%m-%d')
mri_ssp585['time'] = pd.to_datetime(mri_ssp585['time'], format='%Y-%m-%d')


ukesm1_his=xr.open_dataset('ukesm1-0-ll_r1i1p1f2_w5e5_historical_tasmax_global_daily_1941_2014.nc')
ukesm1_ssp126=xr.open_dataset('ukesm1-0-ll_r1i1p1f2_w5e5_ssp126_tasmax_global_daily_2015_2100.nc')
ukesm1_ssp370=xr.open_dataset('ukesm1-0-ll_r1i1p1f2_w5e5_ssp370_tasmax_global_daily_2015_2100.nc')
ukesm1_ssp585=xr.open_dataset('ukesm1-0-ll_r1i1p1f2_w5e5_ssp585_tasmax_global_daily_2015_2100.nc')

tas_his=(gfdl_his+ipsl_his+mpi_his+mri_his+ukesm1_his)/5
ssp126=(gfdl_ssp126+ipsl_ssp126+mpi_ssp126+mri_ssp126+ukesm1_ssp126)/5
ssp370=(gfdl_ssp370+ipsl_ssp370+mpi_ssp370+mri_ssp370+ukesm1_ssp370)/5
ssp585=(gfdl_ssp585+ipsl_ssp585+mpi_ssp585+mri_ssp585+ukesm1_ssp585)/5

gfdl_his = None
ipsl_his = None
mpi_his = None
mri_his = None
ukesm1_his = None

gfdl_ssp126 = None
ipsl_ssp126 = None
mpi_ssp126 = None
mri_ssp126 = None
ukesm1_ssp126 = None

gfdl_ssp370 = None
ipsl_ssp370 = None
mpi_ssp370 = None
mri_ssp370 = None
ukesm1_ssp370 = None

gfdl_ssp585 = None
ipsl_ssp585 = None
mpi_ssp585 = None
mri_ssp585 = None
ukesm1_ssp585 = None


threshold90=tas_his.quantile(0.9, dim="time")
threshold92=tas_his.quantile(0.925, dim="time")
threshold95=tas_his.quantile(0.95, dim="time")
threshold97=tas_his.quantile(0.975, dim="time")
threshold99=tas_his.quantile(0.99, dim="time")
threshold75=tas_his.quantile(0.75, dim="time")
threshold25=tas_his.quantile(0.25, dim="time")

combine_ssp126 = xr.concat([tas_his, ssp126], dim='time')
combine_ssp370 = xr.concat([tas_his, ssp370], dim='time')
combine_ssp585 = xr.concat([tas_his, ssp585], dim='time')


anomaly90_ssp126=combine_ssp126-threshold90
anomaly90_ssp126['tasmax']=xr.where(anomaly90_ssp126['tasmax'] > 0, 1, 0)

anomaly92_ssp126=combine_ssp126-threshold92
anomaly92_ssp126['tasmax']=xr.where(anomaly92_ssp126['tasmax'] > 0, 1, 0)

anomaly95_ssp126=combine_ssp126-threshold95
anomaly95_ssp126['tasmax']=xr.where(anomaly95_ssp126['tasmax'] > 0, 1, 0)

anomaly97_ssp126=combine_ssp126-threshold97
anomaly97_ssp126['tasmax']=xr.where(anomaly97_ssp126['tasmax'] > 0, 1, 0)

anomaly99_ssp126=combine_ssp126-threshold99
anomaly99_ssp126['tasmax']=xr.where(anomaly99_ssp126['tasmax'] > 0, 1, 0)

HWS90_ssp126=(combine_ssp126-threshold75)/(threshold75-threshold25)
HWS90_ssp126=HWS90_ssp126*anomaly90_ssp126
HWS90_ssp126['tasmax']=xr.where(HWS90_ssp126['tasmax'] > 0, HWS90_ssp126['tasmax'], 0)

HWS92_ssp126=(combine_ssp126-threshold75)/(threshold75-threshold25)
HWS92_ssp126=HWS92_ssp126*anomaly92_ssp126
HWS92_ssp126['tasmax']=xr.where(HWS92_ssp126['tasmax'] > 0, HWS92_ssp126['tasmax'], 0)

HWS95_ssp126=(combine_ssp126-threshold75)/(threshold75-threshold25)
HWS95_ssp126=HWS95_ssp126*anomaly95_ssp126
HWS95_ssp126['tasmax']=xr.where(HWS95_ssp126['tasmax'] > 0, HWS95_ssp126['tasmax'], 0)

HWS97_ssp126=(combine_ssp126-threshold75)/(threshold75-threshold25)
HWS97_ssp126=HWS97_ssp126*anomaly97_ssp126
HWS97_ssp126['tasmax']=xr.where(HWS97_ssp126['tasmax'] > 0, HWS97_ssp126['tasmax'], 0)

HWS99_ssp126=(combine_ssp126-threshold75)/(threshold75-threshold25)
HWS99_ssp126=HWS99_ssp126*anomaly99_ssp126
HWS99_ssp126['tasmax']=xr.where(HWS99_ssp126['tasmax'] > 0, HWS99_ssp126['tasmax'], 0)

HWS90_ssp126.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp126_hws90.nc')
HWS92_ssp126.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp126_hws92.nc')
HWS95_ssp126.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp126_hws95.nc')
HWS97_ssp126.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp126_hws97.nc')
HWS99_ssp126.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp126_hws99.nc')

anomaly90_ssp370=combine_ssp370-threshold90
anomaly90_ssp370['tasmax']=xr.where(anomaly90_ssp370['tasmax'] > 0, 1, 0)

anomaly92_ssp370=combine_ssp370-threshold92
anomaly92_ssp370['tasmax']=xr.where(anomaly92_ssp370['tasmax'] > 0, 1, 0)

anomaly95_ssp370=combine_ssp370-threshold95
anomaly95_ssp370['tasmax']=xr.where(anomaly95_ssp370['tasmax'] > 0, 1, 0)

anomaly97_ssp370=combine_ssp370-threshold97
anomaly97_ssp370['tasmax']=xr.where(anomaly97_ssp370['tasmax'] > 0, 1, 0)

anomaly99_ssp370=combine_ssp370-threshold99
anomaly99_ssp370['tasmax']=xr.where(anomaly99_ssp370['tasmax'] > 0, 1, 0)

HWS90_ssp370=(combine_ssp370-threshold75)/(threshold75-threshold25)
HWS90_ssp370=HWS90_ssp370*anomaly90_ssp370
HWS90_ssp370['tasmax']=xr.where(HWS90_ssp370['tasmax'] > 0, HWS90_ssp370['tasmax'], 0)

HWS92_ssp370=(combine_ssp370-threshold75)/(threshold75-threshold25)
HWS92_ssp370=HWS92_ssp370*anomaly92_ssp370
HWS92_ssp370['tasmax']=xr.where(HWS92_ssp370['tasmax'] > 0, HWS92_ssp370['tasmax'], 0)

HWS95_ssp370=(combine_ssp370-threshold75)/(threshold75-threshold25)
HWS95_ssp370=HWS95_ssp370*anomaly95_ssp370
HWS95_ssp370['tasmax']=xr.where(HWS95_ssp370['tasmax'] > 0, HWS95_ssp370['tasmax'], 0)

HWS97_ssp370=(combine_ssp370-threshold75)/(threshold75-threshold25)
HWS97_ssp370=HWS97_ssp370*anomaly97_ssp370
HWS97_ssp370['tasmax']=xr.where(HWS97_ssp370['tasmax'] > 0, HWS97_ssp370['tasmax'], 0)

HWS99_ssp370=(combine_ssp370-threshold75)/(threshold75-threshold25)
HWS99_ssp370=HWS99_ssp370*anomaly99_ssp370
HWS99_ssp370['tasmax']=xr.where(HWS99_ssp370['tasmax'] > 0, HWS99_ssp370['tasmax'], 0)

HWS90_ssp370.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp370_hws90.nc')
HWS92_ssp370.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp370_hws92.nc')
HWS95_ssp370.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp370_hws95.nc')
HWS97_ssp370.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp370_hws97.nc')
HWS99_ssp370.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp370_hws99.nc')

anomaly90_ssp585=combine_ssp585-threshold90
anomaly90_ssp585['tasmax']=xr.where(anomaly90_ssp585['tasmax'] > 0, 1, 0)

anomaly92_ssp585=combine_ssp585-threshold92
anomaly92_ssp585['tasmax']=xr.where(anomaly92_ssp585['tasmax'] > 0, 1, 0)

anomaly95_ssp585=combine_ssp585-threshold95
anomaly95_ssp585['tasmax']=xr.where(anomaly95_ssp585['tasmax'] > 0, 1, 0)

anomaly97_ssp585=combine_ssp585-threshold97
anomaly97_ssp585['tasmax']=xr.where(anomaly97_ssp585['tasmax'] > 0, 1, 0)

anomaly99_ssp585=combine_ssp585-threshold99
anomaly99_ssp585['tasmax']=xr.where(anomaly99_ssp585['tasmax'] > 0, 1, 0)

HWS90_ssp585=(combine_ssp585-threshold75)/(threshold75-threshold25)
HWS90_ssp585=HWS90_ssp585*anomaly90_ssp585
HWS90_ssp585['tasmax']=xr.where(HWS90_ssp585['tasmax'] > 0, HWS90_ssp585['tasmax'], 0)

HWS92_ssp585=(combine_ssp585-threshold75)/(threshold75-threshold25)
HWS92_ssp585=HWS92_ssp585*anomaly92_ssp585
HWS92_ssp585['tasmax']=xr.where(HWS92_ssp585['tasmax'] > 0, HWS92_ssp585['tasmax'], 0)

HWS95_ssp585=(combine_ssp585-threshold75)/(threshold75-threshold25)
HWS95_ssp585=HWS95_ssp585*anomaly95_ssp585
HWS95_ssp585['tasmax']=xr.where(HWS95_ssp585['tasmax'] > 0, HWS95_ssp585['tasmax'], 0)

HWS97_ssp585=(combine_ssp585-threshold75)/(threshold75-threshold25)
HWS97_ssp585=HWS97_ssp585*anomaly97_ssp585
HWS97_ssp585['tasmax']=xr.where(HWS97_ssp585['tasmax'] > 0, HWS97_ssp585['tasmax'], 0)

HWS99_ssp585=(combine_ssp585-threshold75)/(threshold75-threshold25)
HWS99_ssp585=HWS99_ssp585*anomaly99_ssp585
HWS99_ssp585['tasmax']=xr.where(HWS99_ssp585['tasmax'] > 0, HWS99_ssp585['tasmax'], 0)

HWS90_ssp585.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp585_hws90.nc')
HWS92_ssp585.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp585_hws92.nc')
HWS95_ssp585.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp585_hws95.nc')
HWS97_ssp585.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp585_hws97.nc')
HWS99_ssp585.to_netcdf('C:\\Users\yaoxin\Desktop\ISIMIP3b\HWS\\mme_ssp585_hws99.nc')
